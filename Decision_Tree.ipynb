# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSH08072002/Data-Science-Practice-Codes/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import Libraries

import numpy as np
import pandas as pd
df = pd.read_csv('/content/iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#seperation thr training set and test set
from sklearn.model_selection import train_test_split
x = df.drop('species',axis=1)
#x= df.drop('id',axis=1)

y = df['species']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30)
x_train2,x_validation,y_train2,y_validation = train_test_split(x_train,y_train,test_size=0.30)

#import decision tree classifier via sklb ads  earn
from sklearn.tree import DecisionTreeClassifier


#Applying the Decision ntree algorithm using entropy
dtree = DecisionTreeClassifier(criterion='entropy', max_depth=3)
dtree.fit(x_train2,y_train2)
predictions = dtree.predict(x_validation)
predictions2 = dtree.predict(x_test)

#Checking the acccuracy of the model
from sklearn.metrics import accuracy_score
accuracy_score(y_validation,predictions)
# accuracy_score(y_test,predictions2)
# Out:
# 0.9375

# %%
#Applying the decision tree algorith using gini
dtree2 = DecisionTreeClassifier(criterion='gini', max_depth=3)
dtree2.fit(x_train2,y_train2)
predictions = dtree2.predict(x_validation)
predictions2 = dtree2.predict(x_test)
#Checking the acccuracy of the model
from sklearn.metrics import accuracy_score
accuracy_score(y_validation,predictions)
accuracy_score(y_test,predictions2)
# Out:
# 0.9333333333333333

# %%
#Plotting with entropy
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(16,12))
a = plot_tree(dtree, feature_names= df.columns,fontsize=12,filled=True,class_names=['setosa','versicolor','virginica'])

# %%
#Plotting for gini
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(16,12))
a = plot_tree(dtree2, feature_names= df.columns,fontsize=12,filled=True,class_names=['setosa','versicolor','virginica'])
